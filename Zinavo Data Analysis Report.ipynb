# %%
import numpy as np
import pandas as pd

# %%
zinavo=pd.read_csv("zinavo.csv")

# %%
zinavo
# Out:
#             # ---------------------------------------- Unnamed: 1 Unnamed: 2  \
# 0                                             # ZINAVO        NaN        NaN
# 1                                        # All Traffic        NaN        NaN
# 2                                  # 20180101-20181126        NaN        NaN
# 3           # ----------------------------------------        NaN        NaN
# 4                                                  NaN        NaN        NaN
# 5                                      Source / Medium      Users  New Users
# 6                                     google / organic     21,802     21,672
# 7                                    (direct) / (none)      8,724      8,664
# 8                                         google / cpc        563        529
# 9                                 zinavo.in / referral        509        443
# 10                                      bing / organic        223        223
# ...

# %%
zinavo.head()
# Out:
#                # ZINAVO Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0       Source / Medium      Users  New Users   Sessions  Bounce Rate
# 1      google / organic     21,802     21,672     28,172       33.53%
# 2     (direct) / (none)      8,724      8,664     10,602       45.06%
# 3          google / cpc        563        529        666       52.55%
# 4  zinavo.in / referral        509        443        634       53.15%
#
#         Unnamed: 5             Unnamed: 6  \
# 0  Pages / Session  Avg. Session Duration
# 1             2.64               00:02:26
# 2             2.33               00:01:57
# 3             1.88               00:01:11
# 4              2.3               00:02:51
#
#                                          Unnamed: 7  \
# 0  Zinavo Conversion Leads (Goal 1 Conversion Rate)
# 1                                             0.52%
# 2                                             0.23%
# 3                                             0.45%
# ...

# %%
zinavo.describe()
# Out:
#                  # ZINAVO Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# count                  11         12         12         12         12
# unique                 11         12         12         12         11
# top     (direct) / (none)      8,724        223        223    100.00%
# freq                    1          1          1          1          2
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# count          12         12         12         12         12
# unique         11         11          9          8          2
# top             1   00:00:00      0.00%          0      $0.00
# freq            2          2          4          4         11

# %%
zinavo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
# # ZINAVO      11 non-null object
# Unnamed: 1    12 non-null object
# Unnamed: 2    12 non-null object
# Unnamed: 3    12 non-null object
# Unnamed: 4    12 non-null object
# Unnamed: 5    12 non-null object
# Unnamed: 6    12 non-null object
# Unnamed: 7    12 non-null object
# Unnamed: 8    12 non-null object
# Unnamed: 9    12 non-null object
# dtypes: object(10)
# memory usage: 520.0+ bytes

# %%
#zinavo[' Users '].mean()
zinavo.dtypes
# Out:
# # ZINAVO      object
# Unnamed: 1    object
# Unnamed: 2    object
# Unnamed: 3    object
# Unnamed: 4    object
# Unnamed: 5    object
# Unnamed: 6    object
# Unnamed: 7    object
# Unnamed: 8    object
# Unnamed: 9    object
# dtype: object

# %%
print( zinavo.describe() )
# Out:
#                  # ZINAVO Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# count                  11         12         12         12         12
# unique                 11         12         12         12         11
# top     (direct) / (none)      8,724        223        223    100.00%
# freq                    1          1          1          1          2
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# count          12         12         12         12         12
# unique         11         11          9          8          2
# top             1   00:00:00      0.00%          0      $0.00
# freq            2          2          4          4         11

# %%
print( zinavo.count() )
# Out:
# # ZINAVO      11
# Unnamed: 1    12
# Unnamed: 2    12
# Unnamed: 3    12
# Unnamed: 4    12
# Unnamed: 5    12
# Unnamed: 6    12
# Unnamed: 7    12
# Unnamed: 8    12
# Unnamed: 9    12
# dtype: int64

# %%
print( zinavo)
# Out:
#                                              # ZINAVO Unnamed: 1 Unnamed: 2  \
# 0                                     Source / Medium      Users  New Users
# 1                                    google / organic     21,802     21,672
# 2                                   (direct) / (none)      8,724      8,664
# 3                                        google / cpc        563        529
# 4                                zinavo.in / referral        509        443
# 5                                      bing / organic        223        223
# 6   com.google.android.googlequicksearchbox / refe...        127        122
# 7                        clubcabana.net.in / referral         72         69
# 8                           127.0.0.1:8888 / referral         71         71
# 9                     auto-seo-service.org / referral         56         56
# 10                           soravjain.com / referral         55         52
# ...

# %%
zinavo['Title']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-1f696966cea9> in <module>()
# ----> 1 zinavo['Title']
#
# ...

# %%
zinavo
# Out:
#                                              # ZINAVO Unnamed: 1 Unnamed: 2  \
# 0                                     Source / Medium      Users  New Users
# 1                                    google / organic     21,802     21,672
# 2                                   (direct) / (none)      8,724      8,664
# 3                                        google / cpc        563        529
# 4                                zinavo.in / referral        509        443
# 5                                      bing / organic        223        223
# 6   com.google.android.googlequicksearchbox / refe...        127        122
# 7                        clubcabana.net.in / referral         72         69
# 8                           127.0.0.1:8888 / referral         71         71
# 9                     auto-seo-service.org / referral         56         56
# 10                           soravjain.com / referral         55         52
# ...

# %%
zinavo.head(10)
# Out:
#                                             # ZINAVO Unnamed: 1 Unnamed: 2  \
# 0                                    Source / Medium      Users  New Users
# 1                                   google / organic     21,802     21,672
# 2                                  (direct) / (none)      8,724      8,664
# 3                                       google / cpc        563        529
# 4                               zinavo.in / referral        509        443
# 5                                     bing / organic        223        223
# 6  com.google.android.googlequicksearchbox / refe...        127        122
# 7                       clubcabana.net.in / referral         72         69
# 8                          127.0.0.1:8888 / referral         71         71
# 9                    auto-seo-service.org / referral         56         56
#
#   Unnamed: 3   Unnamed: 4       Unnamed: 5             Unnamed: 6  \
# 0   Sessions  Bounce Rate  Pages / Session  Avg. Session Duration
# ...
