# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
df=pd.read_csv("50_Startups.csv")

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df['R&D Spend'].value_counts().head(5)
# Out:
# 0.00         2
# 123334.88    1
# 165349.20    1
# 38558.51     1
# 46014.02     1
# Name: R&D Spend, dtype: int64

# %%
df['Administration'].value_counts().head(5)
# Out:
# 127382.30    1
# 148718.95    1
# 51743.15     1
# 153514.11    1
# 82982.09     1
# Name: Administration, dtype: int64

# %%
df['Marketing Spend'].value_counts().head(5)
# Out:
# 0.00         3
# 46085.25     1
# 383199.62    1
# 107138.38    1
# 205517.64    1
# Name: Marketing Spend, dtype: int64

# %%
df['State'].value_counts().head(5)
# Out:
# California    17
# New York      17
# Florida       16
# Name: State, dtype: int64

# %%
df['Profit'].value_counts().head(5)
# Out:
# 118474.03    1
# 69758.98     1
# 81229.06     1
# 101004.64    1
# 124266.90    1
# Name: Profit, dtype: int64

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
print( df.describe() )
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
categorical = df.dtypes[df.dtypes == "object"].index
print(categorical)
# Out:
# Index(['State'], dtype='object')

# %%
categorical
# Out:
# Index(['State'], dtype='object')

# %%
df["R&D Spend"][0:15]
# Out:
# 0     165349.20
# 1     162597.70
# 2     153441.51
# 3     144372.41
# 4     142107.34
# 5     131876.90
# 6     134615.46
# 7     130298.13
# 8     120542.52
# 9     123334.88
# 10    101913.08
# 11    100671.96
# 12     93863.75
# 13     91992.39
# 14    119943.24
# Name: R&D Spend, dtype: float64

# %%
sorted(df["R&D Spend"])[0:15]
# Out:
# [0.0,
#  0.0,
#  542.05,
#  1000.23,
#  1315.46,
#  15505.73,
#  20229.59,
#  22177.74,
#  23640.93,
#  27892.92,
#  28663.76,
#  28754.33,
#  38558.51,
#  44069.95,
#  46014.02]

# %%
sorted(df["R&D Spend"])[0:15]
# Out:
# [0.0,
#  0.0,
#  542.05,
#  1000.23,
#  1315.46,
#  15505.73,
#  20229.59,
#  22177.74,
#  23640.93,
#  27892.92,
#  28663.76,
#  28754.33,
#  38558.51,
#  44069.95,
#  46014.02]

# %%
print( df.describe() )
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df = pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]})
df['States']="CA NV AZ".split()
df.set_index('States',inplace=True)
print(df)
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
df['States']="CA NV AZ".split()
df.set_index('States')
print(df)
# Out:
#           A    B  C States
# States
# CA      1.0  5.0  1     CA
# NV      2.0  NaN  2     NV
# AZ      NaN  NaN  3     AZ

# %%
df['States']="CA NY FL".split()
df.set_index('States')
print(df)
# Out:
#           A    B  C States
# States
# CA      1.0  5.0  1     CA
# NV      2.0  NaN  2     NY
# AZ      NaN  NaN  3     FL

# %%
df=value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-539d1a500972> in <module>()
# ----> 1 df=value_counts().head(10)
#
# NameError: name 'value_counts' is not defined

# %%
df
# Out:
#           A    B  C States
# States
# CA      1.0  5.0  1     CA
# NV      2.0  NaN  2     NY
# AZ      NaN  NaN  3     FL

# %%
df.head()
# Out:
#           A    B  C States
# States
# CA      1.0  5.0  1     CA
# NV      2.0  NaN  2     NY
# AZ      NaN  NaN  3     FL

# %%
df.tail()
# Out:
#           A    B  C States
# States
# CA      1.0  5.0  1     CA
# NV      2.0  NaN  2     NY
# AZ      NaN  NaN  3     FL

# %%
df.index
# Out:
# Index(['CA', 'NV', 'AZ'], dtype='object', name='States')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'States'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, CA to AZ
# Data columns (total 4 columns):
# A         2 non-null float64
# B         1 non-null float64
# C         3 non-null int64
# States    3 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 96.0+ bytes

# %%
df.plot.hist()
